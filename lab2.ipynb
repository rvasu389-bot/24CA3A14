# %%
import nltk
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\mavi
# [nltk_data]     vaishnav\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\mavi
# [nltk_data]     vaishnav\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
text ="Dr. Ravi is studying machine Learning at Anna University in Chennai."

# %%
tokens=word_tokenize(text)

# %%
print("Input Sentence:")
print(text)
print("\nTokenized Output:")
print(tokens)
# Out:
# Input Sentence:
# Dr. Ravi is studying machine Learning at Anna University in Chennai.
#
# Tokenized Output:
# ['Dr.', 'Ravi', 'is', 'studying', 'machine', 'Learning', 'at', 'Anna', 'University', 'in', 'Chennai', '.']

# %%
import string
from nltk.corpus import stopwords

# %%
import nltk
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\mavi
# [nltk_data]     vaishnav\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
text ="Dr. Ravi is studying machine Learning at Anna University in Chennai."

# %%
tokens = word_tokenize(text)

# %%
stop_words = set(stopwords.words('english'))

filtered_tokens = [
    word
    for word in tokens
    if word.lower() not in stop_words
    and word not in string.punctuation
]

# %%
print("Original Token:")
print(tokens)

print("\nTokens after stop-word & punctuation Removal:")
print(filtered_tokens)
# Out:
# Original Token:
# ['Dr.', 'Ravi', 'is', 'studying', 'machine', 'Learning', 'at', 'Anna', 'University', 'in', 'Chennai', '.']
#
# Tokens after stop-word & punctuation Removal:
# ['Dr.', 'Ravi', 'studying', 'machine', 'Learning', 'Anna', 'University', 'Chennai']

# %%
import nltk
from nltk.stem import porterstemmer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 import nltk
# ----> 2 from nltk.stem import porterstemmer
#
# ImportError: cannot import name 'porterstemmer' from 'nltk.stem' (C:\Users\rvasu\AppData\Local\Programs\Python\Python313\Lib\site-packages\nltk\stem\__init__.py)
