# %% [markdown]
# # Exercise 1: Text Cleaning - Removing unwanted characters and normalizing text

# %% [markdown]
# ## Aim
#
# To perform text cleaning by removing unwanted characters and normalizing text.

# %% [markdown]
# ## Objective
#
# Apply basic text cleaning techniques on a given corpus.
#
#     1. <p>Data Science is AMAZING!!! Visit https://datascience.com</p>
#
#     2. Python 3.12 is released in 2025.
#
#     3. NLP is used in AI.
#
#     4. Contact us at info@gmail.com
#
# ## Expected Output
#
#     1. data science is amazing visit
#
#     2. python is released in
#
#     3. nlp is used in ai
#
#     4. contact us at

# %% [markdown]
# ![slide 1](Slide%201%20Nlp%20lab%201%20statement.png)

# %% [markdown]
# ## Pre-Lab Task:

# %% [markdown]
# ### 1. Define Text Cleaning

# %% [markdown]
# Text Cleaning
#
# The process of transforming raw text into a clean, consistent and structured format suitable for Natural Language Processing (NLP) and Machine Learning tasks.
#
# Definition
#
# Text Cleaning is the process of detecting and removing unwanted elements from text data and standardizing it into a consistent format.
#
# It improves the quality of text data and helps NLP models understand the text better, leading to more accurate results.
#
# Why is it Important?
# Reduces noise and irrelevant information.
# Improves the performance of NLP models.
# Ensures consistency in text representation.
# Helps in better analysis and insights.
# Common Issues in Raw Text
# HTML Tags – Extra HTML or XML tags.
# Numbers – Numbers (when not needed).
# URLs and Links – URLs and links.
# Inconsistent Casing – Example: THIS IS TEXT.
# Email Addresses – Example: info@gmail.com.
# Extra Spaces / Line Breaks – Example: " Too many spaces ".
# Punctuation & Special Characters – Example: !!!,??,.;:-).
# Symbols and Noise – Example: @ # $ % ^ & *.
# What Does Text Cleaning Involve?
# 1. Remove HTML Tags
#
# Eliminates HTML or XML tags from the text.
#
# 2. Remove URLs
#
# Removes web links (http://, https://, www., etc.).
#
# 3. Remove Emails
#
# Deletes email addresses from the text.
#
# 4. Remove Punctuation
#
# Removes punctuation marks, symbols and special characters.
#
# 5. Lowercase Conversion
#
# Converts all text to lowercase for uniformity.
#
# 6. Normalize Spaces
#
# Removes extra spaces, tabs and line breaks to standardize text.
#
# Example
# Raw Text (Example)
#
# <p>Data Science is AMAZING!!! Visit https://datascience.com</p> Contact us at info@gmail.com Now!!!
#
# Cleaned Text (After Cleaning)
#
# data science is amazing visit contact us at now
#
# Key Takeaway
#
# Clean text data leads to better understanding, better features, and better models.
#
# "Clean First, Model Next."
#
# Used In
# Sentiment Analysis
# Text Classification
# Machine Translation
# Information Retrieval
# Chatbots and more...

# %% [markdown]
# ### 2. Write the method used to remove the following
#         1. HTML tags
#         2. URLs
#         3. Email addresses
#         4. Digits
#         5. Extra spaces
#         6. Uppercase letters (converted to lowercase)

# %% [markdown]
# Methods Used for Text Cleaning
# 1. Removing HTML Tags
#
# HTML tags are commonly found in web pages but are not useful for text analysis. They should be removed so that only the readable content remains. This can be done using a regular expression.
#
# Python Code:
#
# import re
#
# cleaned_text = re.sub(r'<.*?>', '', text)
#
# Example:
#
# Input:
#
# <p>Welcome <b>Everyone</b></p>
#
# Output:
#
# Welcome Everyone
# 2. Removing URLs
#
# Web links usually do not contribute to text analysis, so they are removed from the text using regular expressions.
#
# Python Code:
#
# cleaned_text = re.sub(r'https?://\S+|www\.\S+', '', text)
#
# Example:
#
# Input:
#
# Visit https://python.org for tutorials.
#
# Output:
#
# Visit for tutorials.
# 3. Removing Email Addresses
#
# Email IDs are considered unnecessary information for many NLP tasks. A regex pattern can identify and remove them.
#
# Python Code:
#
# cleaned_text = re.sub(r'\b[\w.-]+@[\w.-]+\.\w+\b', '', text)
#
# Example:
#
# Input:
#
# Send your feedback to support@example.com today.
#
# Output:
#
# Send your feedback to today.
# 4. Removing Numbers
#
# In many text processing applications, numerical values are not required and can be removed to keep only meaningful words.
#
# Python Code:
#
# cleaned_text = re.sub(r'\d+', '', text)
#
# Example:
#
# Input:
#
# There are 15 books and 8 pens.
#
# Output:
#
# There are books and pens.
# 5. Removing Extra Spaces
#
# Sometimes text contains multiple spaces, tabs or blank lines. These should be replaced with a single space to improve readability.
#
# Python Code:
#
# cleaned_text = re.sub(r'\s+', ' ', text).strip()
#
# Example:
#
# Input:
#
# This      sentence      has      extra      spaces.
#
# Output:
#
# This sentence has extra spaces.
# 6. Converting Uppercase Letters to Lowercase
#
# Converting all text to lowercase ensures consistency and helps avoid treating words like Python and python as different.
#
# Python Code:
#
# cleaned_text = text.lower()
#
# Example:
#
# Input:
#
# Machine Learning Is AWESOME.
#
# Output:
#
# machine learning is awesome.
# Key Takeaway
#
# Text cleaning is an essential preprocessing step in Natural Language Processing (NLP). By removing unwanted elements such as HTML tags, URLs, email addresses, numbers, unnecessary spaces, and by converting text to lowercase, the data becomes cleaner, more consistent, and easier for machine learning models to process. This ultimately improves the accuracy and efficiency of text analysis.
#
# This version is written in an original, assignment-friendly style rather than matching the infographic word-for-word.

# %% [markdown]
# ### 3. What is the purpose of regular expressions?

# %% [markdown]
# What is the Purpose of Regular Expressions (Regex)?
# Definition
#
# A Regular Expression (Regex) is a sequence of characters used to define a search pattern. It helps identify, search, match, extract, replace, or validate specific patterns within a text. Regex is widely used in programming and data preprocessing because it makes handling text faster and more efficient.
#
# Main Purposes of Regular Expressions
# 1. Searching for Patterns
#
# Regex is used to search for specific words, characters, or patterns within a large amount of text. It quickly finds the required information without checking every word manually.
#
# 2. Removing Unwanted Content
#
# Regular expressions help remove unnecessary text such as HTML tags, URLs, email addresses, numbers, and special symbols. This is an important step in text cleaning before analysis.
#
# 3. Extracting Useful Information
#
# Regex can extract meaningful information from text, such as phone numbers, email addresses, dates, URLs, or other predefined patterns.
#
# 4. Replacing Text
#
# Regex allows matched text to be replaced with another word or symbol. This feature is useful for correcting text, masking sensitive information, or cleaning datasets.
#
# 5. Validating Input
#
# Regular expressions are commonly used to verify whether user input follows a required format. For example, they can validate email addresses, passwords, mobile numbers, PIN codes, or dates.
#
# 6. Cleaning and Preprocessing Text
#
# Before text is used in Natural Language Processing (NLP) or Machine Learning, regex helps clean and organize the data by removing unwanted patterns and making the text consistent.
#
# Common Uses of Regex with Examples
# Remove HTML Tags
#
# Regex Pattern:
#
# r'<.*?>'
#
# Matches: HTML tags enclosed within < >
#
# Example:
#
# Input: <p>Hello <b>World</b></p>
# Output: Hello World
# Remove URLs
#
# Regex Pattern:
#
# r'https?://\S+'
#
# Matches: Web addresses beginning with http or https
#
# Example:
#
# Input: Visit https://example.com today.
# Output: Visit today.
# Remove Email Addresses
#
# Regex Pattern:
#
# r'\b[\w.-]+@[\w.-]+\.\w+\b'
#
# Matches: Valid email addresses
#
# Example:
#
# Input: Contact us at support@gmail.com.
# Output: Contact us at.
# Remove Numbers
#
# Regex Pattern:
#
# r'\d+'
#
# Matches: One or more numeric digits
#
# Example:
#
# Input: I bought 5 books and 12 pens.
# Output: I bought books and pens.
# Remove Extra Spaces
#
# Regex Pattern:
#
# r'\s+'
#
# Matches: Multiple spaces, tabs, or newline characters
#
# Example:
#
# Input: This    is      a      sentence.
# Output: This is a sentence.
# Convert Text to Lowercase
#
# Method:
#
# text.lower()
#
# Purpose: Converts every uppercase letter into lowercase.
#
# Example:
#
# Input: PYTHON Is AMAZING
# Output: python is amazing
# How Does Regex Work?
#
# The working process of a regular expression is simple:
#
# Input Text → Apply Regex Pattern → Pattern is Matched → Perform Required Action (Search, Extract, Replace, or Remove)
#
# Example:
#
# Input Text:
#
# Contact us at support@gmail.com today.
#
# Regex Pattern:
#
# r'\b[\w.-]+@[\w.-]+\.\w+\b'
#
# Matched Text:
#
# support@gmail.com
#
# After Removing:
#
# Contact us at today.
# Regex in Natural Language Processing (NLP)
#
# Regular expressions play an important role in NLP by cleaning raw text before analysis. They remove unnecessary information, standardize text, and improve the quality of data. This preprocessing step helps machine learning models produce more accurate and reliable results.
#
# Key Takeaway
#
# Regular Expressions are powerful pattern-matching tools used to search, extract, replace, validate, and clean text efficiently. They simplify text preprocessing and are widely used in data cleaning, NLP, web scraping, log analysis, and form validation.

# %% [markdown]
# ### 4. Which Python library is used to remove HTML tags?

# %% [markdown]
# Python Library Used to Remove HTML Tags
# Introduction
#
# When working with web data, HTML tags are often included in the text. To make the text clean and readable, these tags need to be removed. The most commonly used Python library for this purpose is BeautifulSoup (bs4).
#
# Why BeautifulSoup?
# Easy to learn and use.
# Extracts only the text by removing HTML tags.
# Handles poorly formatted HTML effectively.
# Commonly used in web scraping and text preprocessing.
# Installation
# pip install beautifulsoup4
# Example Program
# from bs4 import BeautifulSoup
#
# html = "<p>Hello <b>World!</b> Welcome to <a href='https://example.com'>Example</a></p>"
#
# soup = BeautifulSoup(html, "html.parser")
#
# text = soup.get_text()
#
# print(text)
# Output
# Hello World! Welcome to Example
# Other Libraries
# lxml – Faster but requires additional installation and is slightly more complex.
# re (Regular Expressions) – Suitable only for simple HTML; not recommended for complex or nested HTML.
# Conclusion
#
# BeautifulSoup (bs4) is the best choice for removing HTML tags because it is simple, reliable, and widely used. It converts HTML into clean, readable text, making it useful for web scraping, data cleaning, and NLP applications.

# %% [markdown]
# ### 5. What is the difference between \d+ and \W+ in regular expressions?

# %% [markdown]
# Difference Between \d+ and \W+ in Regular Expressions
# Introduction
#
# In Regular Expressions (Regex), different symbols are used to match different types of characters. Two commonly used patterns are \d+ and \W+. Although they look similar, they are used for different purposes.
#
# \d+ (Digits)
#
# The pattern \d+ matches one or more numeric digits (0–9). It is mainly used when you want to find, extract, or remove numbers from text.
#
# Equivalent Pattern:
#
# [0-9]+
#
# Example:
#
# Text:
#
# Order No. 12345, Price: 999
#
# Matches:
#
# 12345
# 999
#
# Common Uses:
#
# Extracting numbers
# Removing digits
# Counting numeric values
# \W+ (Non-Word Characters)
#
# The pattern \W+ matches one or more non-word characters. These include punctuation marks, spaces, and special symbols. It does not match letters, digits, or underscores.
#
# Equivalent Pattern:
#
# [^A-Za-z0-9_]+
#
# Example:
#
# Text:
#
# Hello@World! #2025
#
# Matches:
#
# @
# !
# #
# (space)
#
# Common Uses:
#
# Removing punctuation
# Removing special symbols
# Cleaning unwanted characters
# Word Character (\w)
#
# A word character (\w) includes:
#
# Letters (A–Z, a–z)
# Digits (0–9)
# Underscore (_)
#
# Anything other than these is considered a non-word character (\W).
#
# Key Difference
# \d+ matches one or more digits (0–9).
# \W+ matches one or more non-word characters, such as spaces, punctuation, and symbols.
# Conclusion
#
# Both \d+ and \W+ are useful in text preprocessing. Use \d+ when working with numbers, and use \W+ when removing unwanted symbols or punctuation to make text cleaner and easier to process.

# %% [markdown]
# ## In- Lab Task
#
# ### Tasks
#
#     1. Create a Python list containing the given text corpus.
#     2. Import the required libraries (re and BeautifulSoup).
#     3. Convert all text to lowercase.
#     4. Remove HTML tags.
#     5. Remove URLs.
#     6. Remove email addresses.
#     7. Remove digits.
#     8. Remove punctuation and special characters.
#     9. Remove extra white spaces.
#     10. Store the cleaned text in a new list named cleaned_corpus.
#     11. Display the original corpus and the cleaned corpus.
#     12. Compare the text before and after cleaning.

# %% [markdown]
# #### 1. Create a Python list containing the given text corpus.

# %%
corpus = [
    "<p>Data Science is AMAZING!!! Visit https://datascience.com</p>",
    "Python 3.12 is released in 2025.",
    "NLP is used in AI.",
    "Contact us at info@gmail.com"
]

# %% [markdown]
# #### 2. Import the required libraries (re and BeautifulSoup).

# %%
import re
from bs4 import BeautifulSoup

# %% [markdown]
# #### 3. Convert all text to lowercase.

# %%
for text in corpus:
    text = text.lower()
    print(text)
# Out:
# <p>data science is amazing!!! visit https://datascience.com</p>
# python 3.12 is released in 2025.
# nlp is used in ai.
# contact us at info@gmail.com

# %%
lowercase_corpus = [text.lower() for text in corpus]

print(lowercase_corpus)
# Out:
# ['<p>data science is amazing!!! visit https://datascience.com</p>', 'python 3.12 is released in 2025.', 'nlp is used in ai.', 'contact us at info@gmail.com']

# %% [markdown]
# #### 4. Remove HTML tags.

# %%
html_removed = [
    BeautifulSoup(text, "html.parser").get_text()
    for text in lowercase_corpus
]

print(html_removed)
# Out:
# ['data science is amazing!!! visit https://datascience.com', 'python 3.12 is released in 2025.', 'nlp is used in ai.', 'contact us at info@gmail.com']

# %% [markdown]
# #### 5. Remove URLs.

# %%
url_removed = [
    re.sub(r'https?://\S+|www\.\S+', '', text)
    for text in html_removed
]

print(url_removed)
# Out:
# ['data science is amazing!!! visit ', 'python 3.12 is released in 2025.', 'nlp is used in ai.', 'contact us at info@gmail.com']

# %% [markdown]
# #### 6. Remove email addresses.

# %%
email_removed = [
    re.sub(r'\b[\w\.-]+@[\w\.-]+\.\w+\b', '', text)
    for text in url_removed
]

print(email_removed)
# Out:
# ['data science is amazing!!! visit ', 'python 3.12 is released in 2025.', 'nlp is used in ai.', 'contact us at ']

# %% [markdown]
# #### 7. Remove digits.

# %%
digit_removed = [
    re.sub(r'\d+', '', text)
    for text in email_removed
]

print(digit_removed)
# Out:
# ['data science is amazing!!! visit ', 'python . is released in .', 'nlp is used in ai.', 'contact us at ']

# %% [markdown]
# #### 8. Remove punctuation and special characters.

# %%
punct_removed = [
    re.sub(r'\W+', ' ', text)
    for text in digit_removed
]

print(punct_removed)
# Out:
# ['data science is amazing visit ', 'python is released in ', 'nlp is used in ai ', 'contact us at ']

# %% [markdown]
# #### 9. Remove extra white spaces.

# %%
cleaned_corpus = [
    re.sub(r'\s+', ' ', text).strip()
    for text in punct_removed
]

print(cleaned_corpus)
# Out:
# ['data science is amazing visit', 'python is released in', 'nlp is used in ai', 'contact us at']

# %% [markdown]
# #### 10. Store the cleaned text in a new list named cleaned_corpus.

# %%
print("The cleaned text has been stored in the list 'cleaned_corpus'.")
print(cleaned_corpus)
# Out:
# The cleaned text has been stored in the list 'cleaned_corpus'.
# ['data science is amazing visit', 'python is released in', 'nlp is used in ai', 'contact us at']

# %% [markdown]
# #### 11. Display the original corpus and the cleaned corpus.

# %%
print("Original Corpus:\n")

for sentence in corpus:
    print(sentence)

print("\nCleaned Corpus:\n")

for sentence in cleaned_corpus:
    print(sentence)
# Out:
# Original Corpus:
#
# <p>Data Science is AMAZING!!! Visit https://datascience.com</p>
# Python 3.12 is released in 2025.
# NLP is used in AI.
# Contact us at info@gmail.com
#
# Cleaned Corpus:
#
# data science is amazing visit
# python is released in
# nlp is used in ai
# contact us at

# %% [markdown]
# #### 12. Compare the text before and after cleaning.

# %%
print("Comparison Before and After Cleaning\n")

for original, cleaned in zip(corpus, cleaned_corpus):
    print("Original :", original)
    print("Cleaned  :", cleaned)
    print("-" * 60)
# Out:
# Comparison Before and After Cleaning
#
# Original : <p>Data Science is AMAZING!!! Visit https://datascience.com</p>
# Cleaned  : data science is amazing visit
# ------------------------------------------------------------
# Original : Python 3.12 is released in 2025.
# Cleaned  : python is released in
# ------------------------------------------------------------
# Original : NLP is used in AI.
# Cleaned  : nlp is used in ai
# ------------------------------------------------------------
# Original : Contact us at info@gmail.com
# Cleaned  : contact us at
# ------------------------------------------------------------

# %%
# =============================================================================
# Experiment 1: Text Cleaning - Removing Unwanted Characters and Normalizing Text
# =============================================================================
# Aim:
#     To perform text cleaning by removing unwanted characters and normalize
#     the text using Python.
#
# Objective:
#     Apply basic text cleaning techniques on a given text corpus using
#     Regular Expressions (Regex) and BeautifulSoup.
#
# Preprocessing Techniques Used:
#     1. Convert text to lowercase
#     2. Remove HTML tags
#     3. Remove URLs
#     4. Remove Email addresses
#     5. Remove Digits
#     6. Remove Punctuation and Special Characters
#     7. Remove Extra White Spaces
# =============================================================================


# =============================================================================
# Step 1: Create the Given Text Corpus
# =============================================================================

corpus = [
    "<p>Data Science is AMAZING!!! Visit https://datascience.com</p>",
    "Python 3.12 is released in 2025.",
    "NLP is used in AI.",
    "Contact us at info@gmail.com"
]


# =============================================================================
# Step 2: Import the Required Libraries
# =============================================================================

import re
from bs4 import BeautifulSoup


# =============================================================================
# Step 3: Convert All Text to Lowercase
# =============================================================================

lowercase_corpus = [
    text.lower()
    for text in corpus
]

print("=" * 70)
print("Step 3: Lowercase Conversion")
print("=" * 70)

for text in lowercase_corpus:
    print(text)


# =============================================================================
# Step 4: Remove HTML Tags
# =============================================================================

html_removed = [
    BeautifulSoup(text, "html.parser").get_text()
    for text in lowercase_corpus
]

print("\n" + "=" * 70)
print("Step 4: HTML Tags Removed")
print("=" * 70)

for text in html_removed:
    print(text)


# =============================================================================
# Step 5: Remove URLs
# =============================================================================

url_removed = [
    re.sub(r'https?://\S+|www\.\S+', '', text)
    for text in html_removed
]

print("\n" + "=" * 70)
print("Step 5: URLs Removed")
print("=" * 70)

for text in url_removed:
    print(text)


# =============================================================================
# Step 6: Remove Email Addresses
# =============================================================================

email_removed = [
    re.sub(r'\b[\w\.-]+@[\w\.-]+\.\w+\b', '', text)
    for text in url_removed
]

print("\n" + "=" * 70)
print("Step 6: Email Addresses Removed")
print("=" * 70)

for text in email_removed:
    print(text)


# =============================================================================
# Step 7: Remove Digits
# =============================================================================

digit_removed = [
    re.sub(r'\d+', '', text)
    for text in email_removed
]

print("\n" + "=" * 70)
print("Step 7: Digits Removed")
print("=" * 70)

for text in digit_removed:
    print(text)


# =============================================================================
# Step 8: Remove Punctuation and Special Characters
# =============================================================================

punct_removed = [
    re.sub(r'\W+', ' ', text)
    for text in digit_removed
]

print("\n" + "=" * 70)
print("Step 8: Punctuation and Special Characters Removed")
print("=" * 70)

for text in punct_removed:
    print(text)


# =============================================================================
# Step 9: Remove Extra White Spaces
# =============================================================================

cleaned_corpus = [
    re.sub(r'\s+', ' ', text).strip()
    for text in punct_removed
]

print("\n" + "=" * 70)
print("Step 9: Extra White Spaces Removed")
print("=" * 70)

for text in cleaned_corpus:
    print(text)


# =============================================================================
# Step 10: Store the Cleaned Text
# =============================================================================
# The cleaned text has already been stored in the list 'cleaned_corpus'.

print("\n" + "=" * 70)
print("Step 10: Cleaned Corpus Stored Successfully")
print("=" * 70)

print(cleaned_corpus)


# =============================================================================
# Step 11: Display the Original Corpus and Cleaned Corpus
# =============================================================================

print("\n" + "=" * 70)
print("Original Corpus")
print("=" * 70)

for sentence in corpus:
    print(sentence)

print("\n" + "=" * 70)
print("Cleaned Corpus")
print("=" * 70)

for sentence in cleaned_corpus:
    print(sentence)


# =============================================================================
# Step 12: Compare Before and After Cleaning
# =============================================================================

print("\n" + "=" * 70)
print("Comparison: Original Text vs Cleaned Text")
print("=" * 70)

for original, cleaned in zip(corpus, cleaned_corpus):

    print("Original :", original)
    print("Cleaned  :", cleaned)
    print("-" * 70)


# =============================================================================
# End of Program
# =============================================================================
# Out:
# ...
# Step 3: Lowercase Conversion
# ...
# <p>data science is amazing!!! visit https://datascience.com</p>
# python 3.12 is released in 2025.
# nlp is used in ai.
# contact us at info@gmail.com
#
# ...
# Step 4: HTML Tags Removed
# ...
# data science is amazing!!! visit https://datascience.com
# python 3.12 is released in 2025.
# nlp is used in ai.
# contact us at info@gmail.com
#
# ...
# Step 5: URLs Removed
# ...
# data science is amazing!!! visit
# python 3.12 is released in 2025.
# nlp is used in ai.
# contact us at info@gmail.com
#
# ...
# Step 6: Email Addresses Removed
# ...
# data science is amazing!!! visit
# python 3.12 is released in 2025.
# nlp is used in ai.
# contact us at
#
# ...
# Step 7: Digits Removed
# ...
# data science is amazing!!! visit
# python . is released in .
# nlp is used in ai.
# contact us at
#
# ...
# Step 8: Punctuation and Special Characters Removed
# ...
# data science is amazing visit
# python is released in
# nlp is used in ai
# contact us at
#
# ...
# Step 9: Extra White Spaces Removed
# ...
# data science is amazing visit
# ...

# %% [markdown]
# ## Post Lab

# %% [markdown]
#  Collect five reviews from an online shopping website or social media platform.
#
# Apply the text cleaning techniques learned in this experiment and compare the original and cleaned text.
#
# Write a brief report (100–150 words) explaining the impact of text cleaning on the dataset.

# %% [markdown]
# ### Live Scenario
#
# ABC Electronics is a popular e-commerce company that sells smartphones, laptops, and electronic accessories. Every day, customers post reviews about their shopping experience on the company's website.
#
# Before performing **Sentiment Analysis**, the Data Analytics team must clean the customer reviews because they contain HTML tags, URLs, email addresses, numbers, punctuation marks, emojis, and unnecessary white spaces.
#
# As a Data Scientist, your task is to clean the customer reviews using the text preprocessing techniques learned in this experiment and prepare the dataset for further Natural Language Processing (NLP) tasks.
#
# ---
#
# ### Objectives
#
# - Collect five customer reviews.
# - Apply text cleaning techniques.
# - Compare the original and cleaned reviews.
# - Analyze the impact of text cleaning.
#
# ---

# %% [markdown]
# #### Sample Dataset

# %%
# Customer Reviews

reviews = [
    "<p>Excellent phone!!! 😍 Battery backup is amazing. Visit https://abcshop.com</p>",
    "Worst laptop ever!! 😡 I paid $999 in 2025. Contact support@abcshop.com",
    "Fast delivery 🚚 and excellent packaging. Highly Recommended!!!",
    "<div>Camera quality is AWESOME 📸. Worth every penny!!!</div>",
    "Average product 😐 Delivery was delayed by 3 days. Visit www.shippingupdates.com"
]

print("Original Reviews\n")

for review in reviews:
    print(review)
# Out:
# Original Reviews
#
# <p>Excellent phone!!! 😍 Battery backup is amazing. Visit https://abcshop.com</p>
# Worst laptop ever!! 😡 I paid $999 in 2025. Contact support@abcshop.com
# Fast delivery 🚚 and excellent packaging. Highly Recommended!!!
# <div>Camera quality is AWESOME 📸. Worth every penny!!!</div>
# Average product 😐 Delivery was delayed by 3 days. Visit www.shippingupdates.com

# %% [markdown]
# #### Import Libraries

# %%
import re
from bs4 import BeautifulSoup

# %% [markdown]
# #### Clean the Reviews

# %%
cleaned_reviews = []

for review in reviews:

    # Convert to lowercase
    review = review.lower()

    # Remove HTML tags
    review = BeautifulSoup(review, "html.parser").get_text()

    # Remove URLs
    review = re.sub(r'https?://\S+|www\.\S+', '', review)

    # Remove Email IDs
    review = re.sub(r'\b[\w\.-]+@[\w\.-]+\.\w+\b', '', review)

    # Remove digits
    review = re.sub(r'\d+', '', review)

    # Remove punctuation and special characters
    review = re.sub(r'\W+', ' ', review)

    # Remove extra spaces
    review = re.sub(r'\s+', ' ', review).strip()

    cleaned_reviews.append(review)

# %% [markdown]
# #### Compare Before and After

# %%
print("Comparison of Original and Cleaned Reviews\n")

for original, cleaned in zip(reviews, cleaned_reviews):

    print("Original Review")
    print(original)

    print("\nCleaned Review")
    print(cleaned)

    print("-"*80)
# Out:
# Comparison of Original and Cleaned Reviews
#
# Original Review
# <p>Excellent phone!!! 😍 Battery backup is amazing. Visit https://abcshop.com</p>
#
# Cleaned Review
# excellent phone battery backup is amazing visit
# --------------------------------------------------------------------------------
# Original Review
# Worst laptop ever!! 😡 I paid $999 in 2025. Contact support@abcshop.com
#
# Cleaned Review
# worst laptop ever i paid in contact
# --------------------------------------------------------------------------------
# Original Review
# Fast delivery 🚚 and excellent packaging. Highly Recommended!!!
#
# Cleaned Review
# fast delivery and excellent packaging highly recommended
# --------------------------------------------------------------------------------
# Original Review
# <div>Camera quality is AWESOME 📸. Worth every penny!!!</div>
#
# Cleaned Review
# camera quality is awesome worth every penny
# ...

# %% [markdown]
# ### Report

# %% [markdown]
# <p align="justify">Text cleaning is an essential preprocessing step in Natural Language Processing (NLP). In this activity, customer reviews collected from an e-commerce website were cleaned using techniques such as lowercase conversion, HTML tag removal, URL removal, email address removal, digit removal, punctuation removal, and whitespace normalization. The cleaning process eliminated unwanted information and transformed the reviews into a consistent and readable format. This reduced noise in the dataset and made the text suitable for NLP tasks such as sentiment analysis, text classification, and keyword extraction. Clean and standardized text enables machine learning algorithms to identify meaningful patterns more accurately, thereby improving the overall performance and reliability of analytical models.</p>

# %% [markdown]
# ### Conclusion

# %% [markdown]
# <p align="justify">
# This activity demonstrates that text cleaning is an important preprocessing step in NLP. Removing unwanted characters, HTML tags, URLs, email addresses, numbers, punctuation, and extra spaces improves the quality of textual data and makes it more suitable for machine learning and text analytics applications.
# </p>
